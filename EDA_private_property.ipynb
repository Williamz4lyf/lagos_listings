# %% [markdown]
# # Analyzing the Lagos State Real Estate Market II
# In this project, we will be analyzing the Lagos real estate market in order to understand the relationship between certain important features and price. Our dataset has been collected from the property website `http://privateproperty.com.ng`.
#
# We've previously cleaned this dataset, and it is ready for analysis. The dataset has the following features:
# * `Title`: Title of the Listings
# * `Location`: Address of the Listing
# * `Listing_Type`: i.e. Rent, Sale, Shortlet
# * `Price`: Price for sale or rent. Note that all rental prices are annual rents
# * `Beds`: Number of bedrooms in this listing
# * `Baths`: Number of bathrooms in this listing
# * `Toilets`: Number of Toilets in this listing
# * `City`: City in Lagos where the property is located
# * `Location_Area`: i.e. whether property is located on the Island or Mainland of Lagos.
# * `Date_Added`: Date listing was added
# * `Date_Updated`: Date listing was updated
#
# Let's load the dataset and conduct some preliminary statistical analysis.

# %%
import warnings
warnings.simplefilter(action='ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns
import re
import datetime as dt

# %matplotlib inline
style.use('fivethirtyeight')
# sns.set(style='darkgrid')

# %%
df = pd.read_csv('private_property_listing.csv')
df.head()
# Out:
#                                Title  \
# 0          2 BEDROOM DUPLEX FOR RENT
# 1           3 BEDROOM HOUSE FOR RENT
# 2  3 BEDROOM BLOCK OF FLATS FOR RENT
# 3  3 BEDROOM BLOCK OF FLATS FOR RENT
# 4         3 BEDROOM TERRACE FOR RENT
#
#                                     Location Listing_Type             City  \
# 0                 Lekki Phase 1 Lekki Lagos          Rent            Lekki
# 1                               Ikoyi Lagos          Rent            Ikoyi
# 2   Off Admiralty Lekki Phase 1 Lekki Lagos          Rent            Lekki
# 3         Oniru Oniru Victoria Island Lagos          Rent  Victoria Island
# 4                 Banana Island Ikoyi Lagos          Rent            Ikoyi
#
#   Location_Area       Price  Date_Added Date_Updated  Beds  Baths  Toilets
# 0        Island   6000000.0  2023-02-21   2023-02-21   2.0    3.0      3.0
# 1        Island  10000000.0  2022-12-08   2023-02-21   3.0    3.0      4.0
# 2        Island   5500000.0  2023-02-05   2023-02-21   3.0    3.0      4.0
# 3        Island   6500000.0  2023-02-05   2023-02-21   3.0    3.0      4.0
# 4        Island  16000000.0  2023-01-05   2023-02-21   3.0    3.0      4.0

# %% [markdown]
# ### Preliminary Exploratory Analysis
# We'll use some pandas methods to overview the dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31528 entries, 0 to 31527
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          31528 non-null  object
#  1   Location       31528 non-null  object
#  2   Listing_Type   31528 non-null  object
#  3   City           31528 non-null  object
#  4   Location_Area  31528 non-null  object
#  5   Price          31528 non-null  float64
#  6   Date_Added     31528 non-null  object
#  7   Date_Updated   31528 non-null  object
#  8   Beds           31424 non-null  float64
#  9   Baths          31424 non-null  float64
#  10  Toilets        31424 non-null  float64
# dtypes: float64(4), object(7)
# memory usage: 2.6+ MB

# %%
df.describe(include='all')
# Out:
#                                       Title  \
# count                                 31528
# unique                                  179
# top     3 BEDROOM FLAT & APARTMENT FOR RENT
# freq                                   5879
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
#                                          Location Listing_Type   City  \
# count                                       31528        31528  31528
# unique                                      12452            2     21
# top      Lekki Phase 1 Lekki Phase 1 Lekki Lagos          Rent  Lekki
# freq                                          799        31183  10861
# mean                                          NaN          NaN    NaN
# std                                           NaN          NaN    NaN
# min                                           NaN          NaN    NaN
# 25%                                           NaN          NaN    NaN
# 50%                                           NaN          NaN    NaN
# 75%                                           NaN          NaN    NaN
# max                                           NaN          NaN    NaN
#
#        Location_Area         Price  Date_Added Date_Updated          Beds  \
# count          31528  3.152800e+04       31528        31528  31424.000000
# unique             2           NaN        2486         2361           NaN
# top           Island           NaN  2023-02-09   2023-02-20           NaN
# freq           20454           NaN         246         2309           NaN
# mean             NaN  6.573356e+07         NaN          NaN      2.693992
# std              NaN  6.814720e+09         NaN          NaN      1.476496
# min              NaN  1.000000e+05         NaN          NaN      0.000000
# 25%              NaN  1.200000e+06         NaN          NaN      2.000000
# 50%              NaN  3.000000e+06         NaN          NaN      3.000000
# 75%              NaN  7.000000e+06         NaN          NaN      4.000000
# max              NaN  1.200000e+12         NaN          NaN      9.000000
#
#                Baths       Toilets
# count   31424.000000  31424.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean        2.596710      2.007860
# std         1.649778      2.077203
# min         0.000000      0.000000
# 25%         1.000000      0.000000
# 50%         3.000000      1.000000
# 75%         4.000000      4.000000
# max         9.000000      9.000000

# %% [markdown]
# Update date datatype for future analysis.

# %%
df['Date_Added'] = pd.to_datetime(df['Date_Added'], format='%Y-%m-%d')
df['Date_Updated'] = pd.to_datetime(df['Date_Updated'], format='%Y-%m-%d')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31528 entries, 0 to 31527
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          31528 non-null  object
#  1   Location       31528 non-null  object
#  2   Listing_Type   31528 non-null  object
#  3   City           31528 non-null  object
#  4   Location_Area  31528 non-null  object
#  5   Price          31528 non-null  float64
#  6   Date_Added     31528 non-null  datetime64[ns]
#  7   Date_Updated   31528 non-null  datetime64[ns]
#  8   Beds           31424 non-null  float64
#  9   Baths          31424 non-null  float64
#  10  Toilets        31424 non-null  float64
# dtypes: datetime64[ns](2), float64(4), object(5)
# memory usage: 2.6+ MB

# %% [markdown]
# From this statistical analysis, we see a few things:
# * the most popular kind of listing is a 3-bedroom apartment rental
# * The most popular City for listings is Lekki and the Island is the most popular location area
# * Most of the Listings are Rent listings
# * The values in the price column range from 100,000 to 1.2trillion, however interquartile range is between 1.2million to 7million. The large max value has skewed the mean further to the right of the median. This is a right-skewed distribution.
# * We need to conduct further analysis to see date ranges.
# * On average, properties have 2.7 beds, 2.6 baths and 2 toilets. This reflects the fact we highlighted earlier that the 3-bedroom apartment is the most popular listing.
#
# We'll conduct some further statistical analysis.

# %% [markdown]
# ## Exploratory Data Analysis
# This project analyzes the real estate market in Lagos, Nigeria
#
# Analytical Questions
# 1. What is the average rent per city in Lagos?
# 2. What are the cities with the highest and lowest rents (actual, mean, median)?
# 3. Which cities provide proeprty with rents within mean and median values.
# 4. For a person of X income range, what cities provide optimum rental value for a single person, a married couple, a family of 5 (the average family size in Lagos)?
# 5. Visualize and explain the correlation if any between number of bedrooms and bathrooms and rental value.
# 6. Visualize and explain the correlation if any, between the number of bedrooms and bathroom and city.
# 7. What is the state of affordable housing in Lagos?
#     a. What is the median income in Lagos?
#     b. How much of the property market in available within that range?
#     c. Ratio of demand (available renters) v. supply (number of property within their range)
# 8. What does the dataset tell us about the housing deficit and the skewed housing market in Lagos?
# 9. The rate of change / inflation in the Lagos real estate market
# 10. ...
#
# Next Steps / Things Omitted from the Analysis
# 1. ...
#
#
# Dashboard / App
#
# With:
#
# * Monthly Income
# * Choice of Location / City
# * Number of Beds, Baths, Toilets
# * Preference - Serviced / Not Serviced
# * Preference - Furnished / Not Furnished
#
# Provide user with a list of 10 possible rental options within and around their selection range.

# %% [markdown]
# ### Rental Listings
# We intend to explore the Lagos residential rental market. We'll drop commercial listings, separate the rent listings from the sale listings and conduct EDA on the rent listings.

# %%
commercial_listings = list()
for index, row in df.iterrows():
    if 'COMMERCIAL' in row['Title'] or 'SHOP' in row['Title']:
        commercial_listings.append(index)

df.iloc[commercial_listings]
# Out:
#                                         Title  \
# 15               COMMERCIAL PROPERTY FOR RENT
# 56                              SHOP FOR RENT
# 58                              SHOP FOR RENT
# 60                              SHOP FOR RENT
# 675    5 BEDROOM COMMERCIAL PROPERTY FOR RENT
# ...                                       ...
# 31432            COMMERCIAL PROPERTY FOR RENT
# 31439            COMMERCIAL PROPERTY FOR RENT
# 31441            COMMERCIAL PROPERTY FOR RENT
# 31443            COMMERCIAL PROPERTY FOR RENT
# 31521            COMMERCIAL PROPERTY FOR RENT
#
#                                                 Location Listing_Type  \
# 15                            Lekki Phase 1 Lekki Lagos          Rent
# 56                            Lekki Phase 1 Lekki Lagos          Rent
# 58                            Lekki Phase 1 Lekki Lagos          Rent
# 60                            Lekki Phase 1 Lekki Lagos          Rent
# 675          Airport Road Ajao Estate Isolo Isolo Lagos          Rent
# ...                                                  ...          ...
# 31432   Off Adebimpe Adewunmi Drive, Lekki Phase 1 Le...         Rent
# 31439                   Awolowo Road Falomo Ikoyi Lagos          Rent
# 31441   Adetokunbo Ademola Street Victoria Island Vic...         Rent
# 31443   Gateway City, Opic Junction Magodo Isheri Ike...         Rent
# 31521   By Orchid Hotel, 2nd Toll Gate Lekki Expressw...         Rent
#
#                   City Location_Area       Price Date_Added Date_Updated  \
# 15               Lekki        Island   4000000.0 2023-01-13   2023-02-20
# 56               Lekki        Island   8600000.0 2023-02-03   2023-02-20
# 58               Lekki        Island   2000000.0 2023-02-03   2023-02-20
# 60               Lekki        Island   3603600.0 2023-02-03   2023-02-20
# 675              Isolo      Mainland  10000000.0 2022-09-29   2023-02-20
# ...                ...           ...         ...        ...          ...
# 31432            Lekki        Island    900000.0 2014-06-18   2014-06-18
# 31439            Ikoyi        Island   3500000.0 2014-06-04   2014-06-04
# 31441  Victoria Island        Island  15000000.0 2014-05-20   2014-05-20
# 31443            Ikeja      Mainland   2500000.0 2014-04-29   2014-04-29
# 31521            Lekki        Island  10000000.0 2014-01-29   2014-01-29
#
#        Beds  Baths  Toilets
# 15      0.0    0.0      0.0
# 56      0.0    0.0      0.0
# 58      0.0    0.0      0.0
# 60      0.0    0.0      0.0
# 675     5.0    5.0      5.0
# ...     ...    ...      ...
# 31432   0.0    0.0      0.0
# 31439   0.0    0.0      0.0
# 31441   0.0    0.0      0.0
# 31443   0.0    0.0      0.0
# 31521   0.0    0.0      0.0
#
# [1052 rows x 11 columns]

# %%
df.drop(index=commercial_listings, inplace=True)

# %%
sale = df.loc[df['Listing_Type'] == 'Sale']
rent = df.loc[df['Listing_Type'] == 'Rent']

sale.describe()
# Out:
#               Price        Beds       Baths     Toilets
# count  3.450000e+02  345.000000  345.000000  345.000000
# mean   2.555217e+08    3.223188    3.217391    3.434783
# std    6.115897e+08    1.746936    1.894527    2.344453
# min    8.000000e+05    0.000000    0.000000    0.000000
# 25%    5.500000e+07    2.000000    2.000000    0.000000
# 50%    8.500000e+07    4.000000    4.000000    4.000000
# 75%    2.200000e+08    4.000000    5.000000    5.000000
# max    4.000000e+09    6.000000    6.000000    7.000000

# %% [markdown]
# ### Analysis of Rent Price in Lagos
# Interestingly, all the price outliers in our dataset are in the rental listings. Let's review price listings in the rent dataframe that are 100million and over.

# %%
rent.describe()
# Out:
#               Price          Beds         Baths       Toilets
# count  3.013100e+04  30040.000000  30040.000000  30040.000000
# mean   6.470255e+07      2.743975      2.651798      2.037550
# std    6.970385e+09      1.426424      1.608942      2.066777
# min    1.000000e+05      0.000000      0.000000      0.000000
# 25%    1.200000e+06      2.000000      1.000000      0.000000
# 50%    3.000000e+06      3.000000      3.000000      2.000000
# 75%    7.000000e+06      4.000000      4.000000      4.000000
# max    1.200000e+12      9.000000      9.000000      9.000000

# %%
len(rent['Price'].loc[rent['Price'] >= 100000000])
# Out:
# 783

# %%
rent.loc[rent['Price'] >= 100000000]['City'].value_counts()
# Out:
# Lekki              406
# Ikoyi              116
# Ikeja               87
# Victoria Island     65
# Ajah                39
# Ketu                18
# Surulere            10
# Agege               10
# Isolo                8
# Gbagada              7
# Yaba                 6
# Oshodi               4
# Apapa                3
# Ikorodu Road         2
# Iju                  1
# Mushin               1
# Name: City, dtype: int64

# %% [markdown]
# There are 783 records with price values in excess of 100 million. Most of these properties are in Lekki. Some are clearly outliers, given their City locations. Let's draw a sample of 50 listings from this collection and analyze.

# %%
rent.loc[rent['Price'] >= 100000000].sample(50)
# Out:
#                                      Title  \
# 558              5 BEDROOM DUPLEX FOR RENT
# 164              5 BEDROOM DUPLEX FOR RENT
# 2011            4 BEDROOM TERRACE FOR RENT
# 532              3 BEDROOM DUPLEX FOR RENT
# 13122             5 BEDROOM HOUSE FOR RENT
# 1196             5 BEDROOM DUPLEX FOR RENT
# 9908             5 BEDROOM DUPLEX FOR RENT
# 598              5 BEDROOM DUPLEX FOR RENT
# 2998            10 BEDROOM DUPLEX FOR RENT
# 15173             3 BEDROOM HOUSE FOR RENT
# 13797                        LAND FOR RENT
# 2044     3 BEDROOM BLOCK OF FLATS FOR RENT
# 9859              5 BEDROOM HOUSE FOR RENT
# 401              5 BEDROOM DUPLEX FOR RENT
# 13884            5 BEDROOM DUPLEX FOR RENT
# 13848            5 BEDROOM DUPLEX FOR RENT
# 2458               BLOCK OF FLATS FOR RENT
# 202              5 BEDROOM DUPLEX FOR RENT
# 2830   3 BEDROOM FLAT & APARTMENT FOR RENT
# 2522             4 BEDROOM DUPLEX FOR RENT
# 13121                        LAND FOR RENT
# 2476               BLOCK OF FLATS FOR RENT
# 9338             5 BEDROOM DUPLEX FOR RENT
# 16309            4 BEDROOM DUPLEX FOR RENT
# 9836             5 BEDROOM DUPLEX FOR RENT
# 6956              4 BEDROOM HOUSE FOR RENT
# 9812             4 BEDROOM DUPLEX FOR RENT
# 11285            4 BEDROOM DUPLEX FOR RENT
# 13094            FLAT & APARTMENT FOR RENT
# 2556               BLOCK OF FLATS FOR RENT
# 9578   5 BEDROOM FLAT & APARTMENT FOR RENT
# 14827                        LAND FOR RENT
# 11216            5 BEDROOM DUPLEX FOR RENT
# 17916  3 BEDROOM FLAT & APARTMENT FOR RENT
# 3405         ROOM OR BOYS QUARTER FOR RENT
# 2305               BLOCK OF FLATS FOR RENT
# 9712             4 BEDROOM DUPLEX FOR RENT
# 9741              5 BEDROOM HOUSE FOR RENT
# 2085            4 BEDROOM TERRACE FOR RENT
# 18319            4 BEDROOM DUPLEX FOR RENT
# 13796  3 BEDROOM FLAT & APARTMENT FOR RENT
# 13770            5 BEDROOM DUPLEX FOR RENT
# 3598             4 BEDROOM DUPLEX FOR RENT
# 13782            5 BEDROOM DUPLEX FOR RENT
# 9583             6 BEDROOM DUPLEX FOR RENT
# 16313  2 BEDROOM FLAT & APARTMENT FOR RENT
# 16281           4 BEDROOM TERRACE FOR RENT
# 2232            4 BEDROOM TERRACE FOR RENT
# 16219            5 BEDROOM DUPLEX FOR RENT
# 11341            3 BEDROOM DUPLEX FOR RENT
#
#                                                 Location Listing_Type  \
# 558                                   Osapa Lekki Lagos          Rent
# 164                           Chevron Drive Lekki Lagos          Rent
# 2011                          Lekki Phase 1 Lekki Lagos          Rent
# 532                          Ikate Elegushi Lekki Lagos          Rent
# 13122                     Orchid Hotel Road Lekki Lagos          Rent
# 1196                            Lekki Ikota Lekki Lagos          Rent
# 9908                          Lekki Phase 1 Lekki Lagos          Rent
# 598                             Oral Estate Lekki Lagos          Rent
# 2998                          Banana Island Ikoyi Lagos          Rent
# 15173                   Victory Park Estate Lekki Lagos          Rent
# 13797                         Chevron Drive Lekki Lagos          Rent
# 2044                          Lekki Phase 1 Lekki Lagos          Rent
# 9859                           Lekki County Lekki Lagos          Rent
# 401                           Chevron Drive Lekki Lagos          Rent
# 13884                               Ologolo Lekki Lagos          Rent
# 13848                  Ikate Ikate Elegushi Lekki Lagos          Rent
# 2458    Omole Phase2 Extension Olowora Omole Ikeja La...         Rent
# 202                             Oral Estate Lekki Lagos          Rent
# 2830                          Banana Island Ikoyi Lagos          Rent
# 2522                               Maryland Ikeja Lagos          Rent
# 13121               Jakande Busstop Ologolo Lekki Lagos          Rent
# 2476                            Surulere Surulere Lagos          Rent
# 9338                         Ikate Elegushi Lekki Lagos          Rent
# 16309           Lekki Phase 1 Lekki Phase 1 Lekki Lagos          Rent
# 9836                  Chevron Chevron Drive Lekki Lagos          Rent
# 6956                          Banana Island Ikoyi Lagos          Rent
# 9812    Orchid Road By Chevron Toll Gate Lafiaji Lekk...         Rent
# 11285   Vgc Lekki Lagos Victoria Garden City Lekki La...         Rent
# 13094                                Berger Ikeja Lagos          Rent
# 2556                         Boudilon Ikoyi Ikoyi Lagos          Rent
# 9578               Ikota Villa Estate Ikota Lekki Lagos          Rent
# 14827                           Off Road 4, Lekki Lagos          Rent
# 11216                 Ologolo Lekki Ologolo Lekki Lagos          Rent
# 17916                       Old Ikoyi Ikoyi Ikoyi Lagos          Rent
# 3405                              Victoria Island Lagos          Rent
# 2305        By Deeper Life Church Gbagada Gbagada Lagos          Rent
# 9712             Ikate Lekki Ikate Elegushi Lekki Lagos          Rent
# 9741                         Ikate Elegushi Lekki Lagos          Rent
# 2085                                  Ikoyi Ikoyi Lagos          Rent
# 18319            Carlton Gate Chevron Drive Lekki Lagos          Rent
# 13796            Lekki Phase1 Lekki Phase 1 Lekki Lagos          Rent
# 13770                                        Ajah Lagos          Rent
# 3598               Vgc Victoria Garden City Lekki Lagos          Rent
# 13782                    Osapa London Osapa Lekki Lagos          Rent
# 9583    Ago Palace Way Okota Lagos.. Ago Palace Isolo...         Rent
# 16313        Shoreline Estate Banana Island Ikoyi Lagos          Rent
# 16281                   Lekki Lekki Phase 1 Lekki Lagos          Rent
# 2232                          Lekki Phase 1 Lekki Lagos          Rent
# 16219   Chevy View Estate Opposite Chevron Head Offic...         Rent
# 11341                    Ikoyi, Lagos Ikoyi Ikoyi Lagos          Rent
#
#                   City Location_Area         Price Date_Added Date_Updated  \
# 558              Lekki        Island  1.700000e+08 2022-06-02   2023-02-20
# 164              Lekki        Island  1.800000e+08 2022-06-13   2023-02-20
# 2011             Lekki        Island  1.300000e+08 2022-08-16   2023-02-20
# 532              Lekki        Island  1.000000e+08 2022-07-02   2023-02-20
# 13122            Lekki        Island  2.000000e+08 2022-08-24   2022-10-14
# 1196             Lekki        Island  1.600000e+08 2021-05-26   2023-02-17
# 9908             Lekki        Island  4.700000e+08 2022-09-14   2022-11-26
# 598              Lekki        Island  2.600000e+08 2022-09-02   2023-02-20
# 2998             Ikoyi        Island  1.200000e+10 2022-06-27   2023-02-20
# 15173            Lekki        Island  3.000000e+09 2022-09-12   2022-09-12
# 13797            Lekki        Island  1.000000e+08 2022-07-23   2022-10-04
# 2044             Lekki        Island  1.350000e+08 2022-08-23   2023-02-20
# 9859             Lekki        Island  2.100000e+08 2022-09-06   2022-11-26
# 401              Lekki        Island  1.900000e+08 2022-09-12   2023-02-20
# 13884            Lekki        Island  1.050000e+08 2022-08-01   2022-10-04
# 13848            Lekki        Island  1.500000e+08 2021-08-20   2022-10-04
# 2458             Ikeja      Mainland  1.750000e+08 2022-08-12   2023-02-20
# 202              Lekki        Island  1.400000e+08 2022-09-14   2023-02-20
# 2830             Ikoyi        Island  3.000000e+08 2022-07-02   2023-02-20
# 2522             Ikeja      Mainland  1.650000e+08 2022-07-09   2023-02-20
# 13121            Lekki        Island  2.880000e+08 2022-07-19   2022-10-14
# 2476          Surulere      Mainland  1.300000e+08 2022-07-30   2023-02-20
# 9338             Lekki        Island  1.800000e+08 2022-07-20   2022-12-06
# 16309            Lekki        Island  2.000000e+08 2021-08-20   2022-09-22
# 9836             Lekki        Island  1.300000e+08 2022-07-04   2022-11-26
# 6956             Ikoyi        Island  5.500000e+08 2023-01-25   2023-01-25
# 9812             Lekki        Island  1.100000e+08 2022-06-11   2022-11-26
# 11285            Lekki        Island  1.500000e+08 2022-09-20   2022-11-15
# 13094            Ikeja      Mainland  1.000000e+08 2022-07-20   2022-10-15
# 2556             Ikoyi        Island  6.000000e+09 2022-08-08   2023-02-20
# 9578             Lekki        Island  2.000000e+08 2022-09-05   2022-11-30
# 14827            Lekki        Island  1.400000e+08 2022-09-15   2022-09-15
# 11216            Lekki        Island  1.250000e+08 2022-07-26   2022-11-15
# 17916            Ikoyi        Island  1.800000e+08 2022-01-19   2022-01-19
# 3405   Victoria Island        Island  1.750000e+08 2022-07-21   2023-02-18
# 2305           Gbagada      Mainland  2.500000e+08 2022-08-04   2023-02-20
# 9712             Lekki        Island  1.100000e+08 2022-06-11   2022-11-26
# 9741             Lekki        Island  1.700000e+08 2022-09-06   2022-11-26
# 2085             Ikoyi        Island  4.500000e+08 2023-08-25   2023-02-20
# 18319            Lekki        Island  1.500000e+08 2021-09-28   2021-09-28
# 13796            Lekki        Island  1.900000e+08 2022-07-08   2022-10-04
# 13770             Ajah        Island  1.000000e+08 2022-09-19   2022-10-04
# 3598             Lekki        Island  1.900000e+08 2022-06-02   2023-02-18
# 13782            Lekki        Island  1.400000e+08 2021-08-20   2022-10-04
# 9583             Isolo      Mainland  1.600000e+08 2022-09-06   2022-11-30
# 16313            Ikoyi        Island  1.800000e+08 2020-02-05   2022-08-30
# 16281            Lekki        Island  1.550000e+08 2021-11-02   2022-10-30
# 2232             Lekki        Island  1.700000e+08 2022-08-11   2023-02-20
# 16219            Lekki        Island  1.400000e+08 2022-01-13   2023-01-04
# 11341            Ikoyi        Island  3.200000e+08 2022-05-09   2022-11-15
#
#        Beds  Baths  Toilets
# 558     5.0    5.0      6.0
# 164     5.0    5.0      6.0
# 2011    4.0    4.0      5.0
# 532     3.0    3.0      4.0
# 13122   5.0    0.0      0.0
# 1196    5.0    5.0      0.0
# 9908    5.0    5.0      6.0
# 598     5.0    5.0      6.0
# 2998    NaN    NaN      NaN
# 15173   3.0    3.0      4.0
# 13797   0.0    0.0      0.0
# 2044    3.0    3.0      4.0
# 9859    5.0    5.0      6.0
# 401     5.0    5.0      6.0
# 13884   5.0    5.0      6.0
# 13848   5.0    6.0      0.0
# 2458    0.0    0.0      0.0
# 202     5.0    5.0      6.0
# 2830    3.0    3.0      3.0
# 2522    4.0    5.0      5.0
# 13121   0.0    0.0      0.0
# 2476    0.0    0.0      0.0
# 9338    5.0    0.0      0.0
# 16309   4.0    5.0      0.0
# 9836    5.0    5.0      6.0
# 6956    4.0    4.0      5.0
# 9812    4.0    4.0      5.0
# 11285   4.0    4.0      5.0
# 13094   0.0    0.0      0.0
# 2556    0.0    0.0      0.0
# 9578    5.0    6.0      6.0
# 14827   0.0    0.0      0.0
# 11216   5.0    5.0      6.0
# 17916   3.0    3.0      0.0
# 3405    0.0    0.0      0.0
# 2305    0.0    0.0      0.0
# 9712    4.0    4.0      5.0
# 9741    5.0    5.0      6.0
# 2085    4.0    4.0      5.0
# 18319   4.0    4.0      0.0
# 13796   3.0    3.0      4.0
# 13770   5.0    6.0      6.0
# 3598    4.0    5.0      0.0
# 13782   5.0    6.0      0.0
# 9583    6.0    6.0      6.0
# 16313   2.0    2.0      0.0
# 16281   4.0    4.0      0.0
# 2232    4.0    4.0      5.0
# 16219   5.0    6.0      0.0
# 11341   3.0    3.0      0.0

# %% [markdown]
# From the sample, these values are clearly outlier values. We'll drop these values and plot the rent distribution.

# %%
rent.drop(index=rent.loc[rent['Price'] >= 100000000].index, inplace=True)

# %%
rent.describe()
# Out:
#               Price          Beds         Baths       Toilets
# count  2.934800e+04  29263.000000  29263.000000  29263.000000
# mean   6.073462e+06      2.715921      2.622185      2.004955
# std    1.082909e+07      1.412563      1.593109      2.045183
# min    1.000000e+05      0.000000      0.000000      0.000000
# 25%    1.200000e+06      2.000000      1.000000      0.000000
# 50%    3.000000e+06      3.000000      3.000000      2.000000
# 75%    6.000000e+06      4.000000      4.000000      4.000000
# max    9.900000e+07      9.000000      9.000000      9.000000

# %%
rent['Price'].plot.hist(bins=20)

locs, labels = plt.xticks()
labels = ['<20M', '0', '20M', '40M',
          '60M', '80M', '100M', '120M']

plt.xticks(ticks=locs[1:], labels=labels[1:])
plt.xlabel('Rent')
plt.title('Distribution of Rental Prices')
plt.show()

# %% [markdown]
# The average and standard deviation values for price have significantly reduced. However, the distribution remains very right-skewed. Let's see the distribution of price values below the 25th percentile and above the 75th percentile

# %%
price_u25 = rent['Price'].loc[rent['Price'] < rent['Price'].describe()[4]]
price_o75 = rent['Price'].loc[rent['Price'] > rent['Price'].describe()[-2]]

# %%
len(price_u25)
# Out:
# 7078

# %%
ax = price_u25.plot.hist()
price_u25.plot(kind='kde', ax=ax,
               secondary_y=True, color='green')

locs = ax.get_xticks()
labels = ax.get_xticklabels()
labels = ['<1M', '<500k', '0', '500k', '1M', '1.5M', '2M']
ax.set_xticks(ticks=locs[2:-1], labels=labels[2:-1])
ax.set_xlabel('Rent')
plt.title('Distribution of the Under 1.2M Rents')
plt.show()

# %% [markdown]
# There are 7,078 records below the 25th percentile and their distribution looks slightly uniform and slightly normal. Using only the kernel density plot, it looks even more normal. Let's review its mean, median and mode to determine what kind of distribution this plot is.

# %%
price_u25.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
price_u25.describe()
# Out:
# count    7.078000e+03
# mean     6.463907e+05
# std      2.510097e+05
# min      1.000000e+05
# 25%      4.500000e+05
# 50%      6.500000e+05
# 75%      8.500000e+05
# max      1.150000e+06
# Name: Price, dtype: float64

# %%
price_u25.mode()
# Out:
# 0    1000000.0
# Name: Price, dtype: float64

# %% [markdown]
# The mode is to the right of the median, which is slightly to the right of the mean. This distribution is left-skewed. The majority of the distribution is under 1million. This means that for lower income renters, the majority of properties have an annual rental value under NGN1 million. However, with a median rental value of NGN650,000, renters looking to rent within the lower range are expected to earn an annual income of around NGN2.16million (or NGN180,550/ month) in order for rent to be the recommended 30% of their income.
#
# In Nigeria, middle class earners have an income range within NGN75,000 - NGN100,000 a month. For this class, who are interested in renting in the lower rent market, 72-83% of their income will be spent on rent.

# %%
(price_u25 < 1000000).sum()
# Out:
# 6006

# %%
(price_u25 > 1000000).sum()
# Out:
# 180

# %% [markdown]
# Let's plot the over 75th percentile of the price variable.

# %%
ax = price_o75.plot.hist()
price_o75.plot(kind='kde', ax=ax,
               secondary_y=True, color='green')

locs = ax.get_xticks()
labels = ax.get_xticklabels()
labels = ['<50M', '<25M', '0', '25M', '50M',
          '75M', '100M', '125M', '150M', '175M']
ax.set_xticks(ticks=locs[2:-1], labels=labels[2:-1])
ax.set_xlabel('Rent')
plt.title('Distribution of the 25M & Above Rents')
plt.show()

# %%
len(price_o75)
# Out:
# 7134

# %% [markdown]
# There are more listings in the over 75th percentile range (7134) than in the under 25th percentile range (7078). This raises an issue concerning affordable housing within the city.

# %%
(price_o75 <= 25000000).sum()
# Out:
# 6107

# %% [markdown]
# The over 75th percentile distribution is right-skewed and the majority of the distribution has values under 25million. Let's plot the price distribution for price values below 50M and below 25M.

# %%
rent['Price'].loc[rent['Price'] < 50000000].plot.hist(bins=20)
locs, labels = plt.xticks()
labels = ['<10M', '0', '10M', '20', '30M', '40M', '50M', '60M']

plt.xticks(ticks=locs[1:-2], labels=labels[1:-2])
plt.xlabel('Rent')
plt.title('Distribution of the Rent Price < 50M')
plt.show()

# %%
rent['Price'].loc[rent['Price'] < 25000000].plot.hist(bins=20)
locs, labels = plt.xticks()
labels = ['<5M', '0', '5M', '10M', '15M', '20M', '25M', '30M']

plt.xticks(ticks=locs[1:-1], labels=labels[1:-1])
plt.xlabel('Rent')
plt.title('Distribution of the Rent Price < 25M')
plt.show()

# %% [markdown]
# Our analysis of the price feature tells us the following:
# * The price range in the rental dataset is very wide, however most of the listings are under 25million.
# * The dataset is right-skewed. 20.5% of the dataset have values under NGN1million. Another 21% have values in the range between NGN6 million and NGN25 million. The remainder 60% (less a very small minority) is in the IQR.
#
# We will drop all records where the price is over NGN25 million.

# %%
rent.drop(index=(rent.loc[rent['Price'] > 25000000]).index, inplace=True)
rent.sample(30)
# Out:
#                                      Title  \
# 16740            3 BEDROOM DUPLEX FOR RENT
# 3878   2 BEDROOM FLAT & APARTMENT FOR RENT
# 3510             4 BEDROOM DUPLEX FOR RENT
# 15544  2 BEDROOM FLAT & APARTMENT FOR RENT
# 29972  3 BEDROOM FLAT & APARTMENT FOR RENT
# 4285              4 BEDROOM HOUSE FOR RENT
# 2577                         LAND FOR RENT
# 8801     3 BEDROOM BLOCK OF FLATS FOR RENT
# 4208   3 BEDROOM FLAT & APARTMENT FOR RENT
# 12779  3 BEDROOM FLAT & APARTMENT FOR RENT
# 6036   2 BEDROOM FLAT & APARTMENT FOR RENT
# 18905            4 BEDROOM DUPLEX FOR RENT
# 2566     3 BEDROOM BLOCK OF FLATS FOR RENT
# 4500     2 BEDROOM BLOCK OF FLATS FOR RENT
# 25009           3 BEDROOM TERRACE FOR RENT
# 15088  3 BEDROOM FLAT & APARTMENT FOR RENT
# 23458             5 BEDROOM HOUSE FOR RENT
# 8643   3 BEDROOM FLAT & APARTMENT FOR RENT
# 17634           4 BEDROOM TERRACE FOR RENT
# 18819  2 BEDROOM FLAT & APARTMENT FOR RENT
# 18997  3 BEDROOM FLAT & APARTMENT FOR RENT
# 5571             4 BEDROOM DUPLEX FOR RENT
# 28157             5 BEDROOM HOUSE FOR RENT
# 23517    2 BEDROOM BLOCK OF FLATS FOR RENT
# 19515  3 BEDROOM FLAT & APARTMENT FOR RENT
# 23689  3 BEDROOM FLAT & APARTMENT FOR RENT
# 8918             4 BEDROOM DUPLEX FOR RENT
# 30022  2 BEDROOM FLAT & APARTMENT FOR RENT
# 30888            4 BEDROOM DUPLEX FOR RENT
# 7516       1 BEDROOM SELF CONTAIN FOR RENT
#
#                                                 Location Listing_Type  \
# 16740             Lekki County, Ikota Ikota Lekki Lagos          Rent
# 3878                 Idado Lekki Expressway Lekki Lagos          Rent
# 3510                        Parkview Estate Ikoyi Lagos          Rent
# 15544                      Ramlat Timson Surulere Lagos          Rent
# 29972   Off Adeniyi Jones Avenue, Ikeja Ikeja Ikeja L...         Rent
# 4285           Oniru Estate Oniru Victoria Island Lagos          Rent
# 2577    Ishaga Ishagha Ifako Ogba Extension Ogba Ikej...         Rent
# 8801                                 Agungi Lekki Lagos          Rent
# 4208                              Victoria Island Lagos          Rent
# 12779                         Chevron Drive Lekki Lagos          Rent
# 6036                               Sangotedo Ajah Lagos          Rent
# 18905               Orchid Lekki Expressway Lekki Lagos          Rent
# 2566    Off Ikola Road Command Via Meiran Alimosho Ab...         Rent
# 4500        Off Second Avenue Banana Island Ikoyi Lagos          Rent
# 25009             Lekki Gardens Phase 2 Ajah Ajah Lagos          Rent
# 15088                                       Lekki Lagos          Rent
# 23458                                 Osapa Lekki Lagos          Rent
# 8643               Off Market Street Shomolu Yaba Lagos          Rent
# 17634                  Ikate Ikate Elegushi Lekki Lagos          Rent
# 18819   Glory Land Estate. Abuleodu Egbeda Egbeda Age...         Rent
# 18997                    Idado Estate Idado Lekki Lagos          Rent
# 5571                          Lekki Phase 1 Lekki Lagos          Rent
# 28157   Southern View Estate, Chevron Drive, Lekki Le...         Rent
# 23517   Parkview Estate,ikoyi Lagos Parkview Estate I...         Rent
# 19515                     Lekki Ikota Ikota Lekki Lagos          Rent
# 23689                        1 Eletu Awoyaya Ajah Lagos          Rent
# 8918                        Parkview Estate Ikoyi Lagos          Rent
# 30022   Adenle Road, Adjacent Gowon Estate, Egbeda Ab...         Rent
# 30888       Chevy View Estate Chevron Drive Lekki Lagos          Rent
# 7516                                        Lekki Lagos          Rent
#
#                   City Location_Area       Price Date_Added Date_Updated  \
# 16740            Lekki        Island   3500000.0 2022-01-11   2022-05-25
# 3878             Lekki        Island   3000000.0 2022-05-18   2023-02-18
# 3510             Ikoyi        Island   8000000.0 2022-08-13   2023-02-18
# 15544         Surulere      Mainland   1300000.0 2022-09-07   2022-09-07
# 29972            Ikeja      Mainland   3000000.0 2015-02-24   2015-02-24
# 4285   Victoria Island        Island   4500000.0 2023-02-16   2023-02-16
# 2577             Ikeja      Mainland   8500000.0 2022-08-04   2023-02-20
# 8801             Lekki        Island   2700000.0 2022-12-19   2022-12-19
# 4208   Victoria Island        Island   8000000.0 2023-02-16   2023-02-16
# 12779            Lekki        Island   3750000.0 2022-10-21   2022-10-21
# 6036              Ajah        Island    900000.0 2023-02-06   2023-02-06
# 18905            Lekki        Island   5500000.0 2021-06-15   2021-06-15
# 2566          Alimosho      Mainland  25000000.0 2022-06-27   2023-02-20
# 4500             Ikoyi        Island  13500000.0 2023-02-06   2023-02-15
# 25009             Ajah        Island   1500000.0 2016-06-27   2016-06-27
# 15088            Lekki        Island   4500000.0 2022-09-13   2022-09-13
# 23458            Lekki        Island   4000000.0 2017-01-27   2017-01-27
# 8643              Yaba      Mainland   1200000.0 2022-12-20   2022-12-20
# 17634            Lekki        Island   6000000.0 2022-03-24   2022-03-24
# 18819            Agege      Mainland    900000.0 2021-07-04   2021-07-04
# 18997            Lekki        Island   2500000.0 2021-05-30   2021-05-30
# 5571             Lekki        Island  12000000.0 2023-02-08   2023-02-08
# 28157            Lekki        Island   2500000.0 2015-09-01   2015-09-01
# 23517            Ikoyi        Island   2000000.0 2017-01-04   2017-01-04
# 19515            Lekki        Island   2500000.0 2020-12-07   2020-12-07
# 23689             Ajah        Island    700000.0 2016-11-15   2016-11-15
# 8918             Ikoyi        Island  10000000.0 2022-08-05   2022-12-15
# 30022            Agege      Mainland    400000.0 2015-02-18   2015-02-18
# 30888            Lekki        Island   2700000.0 2014-11-24   2014-11-24
# 7516             Lekki        Island    550000.0 2023-01-19   2023-01-19
#
#        Beds  Baths  Toilets
# 16740   3.0    4.0      0.0
# 3878    2.0    3.0      0.0
# 3510    4.0    4.0      5.0
# 15544   2.0    0.0      0.0
# 29972   3.0    3.0      0.0
# 4285    4.0    4.0      5.0
# 2577    0.0    0.0      0.0
# 8801    3.0    3.0      4.0
# 4208    3.0    3.0      4.0
# 12779   3.0    3.0      4.0
# 6036    2.0    2.0      3.0
# 18905   4.0    4.0      0.0
# 2566    3.0    3.0      3.0
# 4500    2.0    3.0      3.0
# 25009   3.0    3.0      4.0
# 15088   3.0    3.0      4.0
# 23458   5.0    6.0      0.0
# 8643    3.0    2.0      3.0
# 17634   4.0    4.0      0.0
# 18819   2.0    2.0      0.0
# 18997   3.0    3.0      0.0
# 5571    4.0    4.0      5.0
# 28157   5.0    3.0      0.0
# 23517   2.0    2.0      3.0
# 19515   3.0    3.0      4.0
# 23689   3.0    4.0      4.0
# 8918    4.0    4.0      5.0
# 30022   2.0    2.0      0.0
# 30888   4.0    4.0      0.0
# 7516    1.0    1.0      1.0

# %% [markdown]
# Finally, let's consider which features are most correlated with rent. We'll consider location area, along with beds, baths and toilets. Let's encode the location area column as follows:
# 1 = Island
# 0 = Mainland

# %%
rent.head()
# Out:
#                                Title  \
# 0          2 BEDROOM DUPLEX FOR RENT
# 1           3 BEDROOM HOUSE FOR RENT
# 2  3 BEDROOM BLOCK OF FLATS FOR RENT
# 3  3 BEDROOM BLOCK OF FLATS FOR RENT
# 4         3 BEDROOM TERRACE FOR RENT
#
#                                     Location Listing_Type             City  \
# 0                 Lekki Phase 1 Lekki Lagos          Rent            Lekki
# 1                               Ikoyi Lagos          Rent            Ikoyi
# 2   Off Admiralty Lekki Phase 1 Lekki Lagos          Rent            Lekki
# 3         Oniru Oniru Victoria Island Lagos          Rent  Victoria Island
# 4                 Banana Island Ikoyi Lagos          Rent            Ikoyi
#
#   Location_Area       Price Date_Added Date_Updated  Beds  Baths  Toilets
# 0        Island   6000000.0 2023-02-21   2023-02-21   2.0    3.0      3.0
# 1        Island  10000000.0 2022-12-08   2023-02-21   3.0    3.0      4.0
# 2        Island   5500000.0 2023-02-05   2023-02-21   3.0    3.0      4.0
# 3        Island   6500000.0 2023-02-05   2023-02-21   3.0    3.0      4.0
# 4        Island  16000000.0 2023-01-05   2023-02-21   3.0    3.0      4.0

# %%
rent['Location_Area_Encoded'] = rent['Location_Area'].apply(lambda x: 1 if x == 'Island' else 0)

# %%
rent.corr()['Price']
# Out:
# Price                    1.000000
# Beds                     0.378159
# Baths                    0.371857
# Toilets                  0.208933
# Location_Area_Encoded    0.387092
# Name: Price, dtype: float64

# %% [markdown]
# Beds, baths, and location area are positively correlated with price.

# %% [markdown]
# ### How Housing is Spread by Location in Lagos
# Location is a huge part of searching for residential rentals. We've segmented our dataset along City and Location Area lines. We'll explore the records to find patterns.

# %%
rent['Location_Area'].value_counts()
# Out:
# Island      18147
# Mainland    10174
# Name: Location_Area, dtype: int64

# %%
rent['Location_Area'].value_counts().plot.bar(width=.25, rot=.35,
                                              color=['#0000FF',
                                                     '#069AF3'])
plt.ylabel('Number of Listings')
plt.title('Island v. Mainland Listings')
plt.show()

# %% [markdown]
# There are nearly twice as many listings on the Island as are on the Mainland. Let's chart average and median rent between both location areas.

# %%
legend = ['Average Rent']
rent.groupby('Location_Area').agg({'Price':np.mean}).plot.bar(width=.25, rot=.35,
                                                              color='#0343DF',
                                                              label=legend)
locs, labels = plt.yticks()
labels = ['0', '1M', '2M', '3M', '4M', '5M', '6M', '7M']

plt.yticks(ticks=locs, labels=labels)
plt.ylabel('Rent')
plt.xlabel('Location Area')
plt.title('Average Price by Location Area')
plt.legend(labels=legend)
plt.show()

# %%
rent.groupby('Location_Area').agg({'Price':np.median}).plot.bar(width=.25, rot=.35,
                                                                color='#0343DF',
                                                                label='Median Rent')
locs, labels = plt.yticks()
labels = ['0', '500K', '1M', '1.5M', '2M',
          '2.5M', '3M', '3.5M', '4M', '4.5M']

plt.yticks(ticks=locs, labels=labels)
plt.ylabel('Rent')
plt.xlabel('Location Area')
plt.title('Median Price by Location Area')
plt.legend(labels=['Median Rent'])
plt.show()

# %% [markdown]
# More properties are listed on the Island than on the Mainland. The average price difference between location areas is much wider. On average, rent on the Mainland is NGN2 million, while rent on the Island is slightly under NGN6 million. Median rent on the Mainland is around 1.2 million and NGN4 million on the Island.
#
# The top 10 cities with the highest & lowest average and median rents are plotted below:

# %%
top_10_mean = rent.groupby('City').agg({'Price': np.mean}).sort_values(by='Price', ascending=False).reset_index()[:10]
top_10_mean = top_10_mean.sort_values('Price').set_index('City')

top_10_median = rent.groupby('City').agg({'Price': np.median}).sort_values(by='Price', ascending=False).reset_index()[:10]
top_10_median = top_10_median.sort_values('Price').set_index('City')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 12))
ax1.barh(top_10_mean.index, top_10_mean['Price'])
ax2.barh(top_10_median.index, top_10_median['Price'])
fig.suptitle('Top 10 Cities \n Average v. Median Rent', size=30, weight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# The top 5 cities with the highest in average and median rent prices are identical.

# %%
bottom_10_mean = rent.groupby('City').agg({'Price': np.mean}).sort_values(by='Price', ascending=False).reset_index()[-10:]
bottom_10_mean = bottom_10_mean.sort_values('Price').set_index('City')

bottom_10_median = rent.groupby('City').agg({'Price': np.median}).sort_values(by='Price', ascending=False).reset_index()[-10:]
bottom_10_median = bottom_10_median.sort_values('Price').set_index('City')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 12))
ax1.barh(bottom_10_mean.index, bottom_10_mean['Price'])
ax2.barh(bottom_10_median.index, bottom_10_median['Price'])
fig.suptitle('Bottom 10 Cities \n Average v. Median Rent', size=30, weight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# The average and median rent in the most expensive city is over 10x the average and median rent in the least expensive cities.

# %%
rent.groupby('City').agg('count').sort_values(by='Title', ascending=True)['Title'][-10:].plot.barh()
plt.xlabel('Number of Listings')
plt.ylabel('City')
plt.title('Top 10 Cities by Number of Listings')
plt.show()

# %% [markdown]
# The top location for listings is Lekki, having almost 2.5x more listings than the 2nd most popular location, Ikoyi. Only 3 cities from the low rent market is featured in the chart (Yaba, Surulere and Agege). The remainder are in the high rent market.

# %% [markdown]
# ### Property Sizes - Beds, Baths and Toilets

# %%
rent.boxplot(column=['Beds', 'Baths', 'Toilets'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# The median value in the dataset is a 3 bed, 3 bath, 2 toilet home. This makes sense given that the residential market may be populated by single families, with an average size of 5. We see some significant outliers, including values above 6. Let's check to see what kind of listings / properties these are

# %% [markdown]
# ### How Have Listings Evolved Over the Years

# %%
rent['Date_Added'].min()
# Out:
# Timestamp('2013-09-02 00:00:00')

# %%
rent['Date_Added'].max()
# Out:
# Timestamp('2023-06-02 00:00:00')

# %% [markdown]
# The oldest listing is from September 2013 and the newest is from June 2023. Given today's date (24th February), this is an erroneous listing. Let's analyze it.

# %%
rent.loc[rent['Date_Added'] == rent['Date_Added'].max()]
# Out:
#                                   Title  \
# 2275  3 BEDROOM BLOCK OF FLATS FOR RENT
#
#                                                Location Listing_Type   City  \
# 2275   Prime Water Garden 2 Lekki Expressway Lekki L...         Rent  Lekki
#
#      Location_Area      Price Date_Added Date_Updated  Beds  Baths  Toilets  \
# 2275        Island  3500000.0 2023-06-02   2023-02-20   3.0    3.0      4.0
#
#       Location_Area_Encoded
# 2275                      1

# %% [markdown]
# This is an error that can be quickly changed. Given the value in date updated, we can update the month value in date added to February

# %%
rent.at[2275, 'Date_Added'] = '2023-02-06'
rent.at[2275, 'Date_Added']
# Out:
# Timestamp('2023-02-06 00:00:00')

# %%
rent.loc[2275]
# Out:
# Title                                    3 BEDROOM BLOCK OF FLATS FOR RENT
# Location                  Prime Water Garden 2 Lekki Expressway Lekki L...
# Listing_Type                                                          Rent
# City                                                                 Lekki
# Location_Area                                                       Island
# Price                                                            3500000.0
# Date_Added                                             2023-02-06 00:00:00
# Date_Updated                                           2023-02-20 00:00:00
# Beds                                                                   3.0
# Baths                                                                  3.0
# Toilets                                                                4.0
# Location_Area_Encoded                                                    1
# Name: 2275, dtype: object

# %% [markdown]
# Let's check for the max values again

# %%
rent['Date_Added'].max()
# Out:
# Timestamp('2023-02-22 00:00:00')

# %% [markdown]
# The new max value is 22nd of February.
# Let's conduct the same analysis on the date updated column.

# %%
rent['Date_Updated'].min()
# Out:
# Timestamp('2013-09-02 00:00:00')

# %%
rent['Date_Updated'].max()
# Out:
# Timestamp('2023-02-22 00:00:00')

# %% [markdown]
# The date updated values look fine. The oldest update is from September 2013 and the newest value is from February 2023.
#
# From this analysis, we can tell that the spread of the chart is 10 years. Let's chart average and median price over the 10 year period.

# %%
rent.groupby(by=[rent.Date_Added.dt.year,  rent.Date_Added.dt.month]).agg({'Price':np.mean})
# Out:
#                               Price
# Date_Added Date_Added
# 2013       9           5.500000e+06
#            10          2.355000e+07
#            12          1.500000e+06
# 2014       1           2.000000e+06
#            3           2.650000e+06
# ...                             ...
# 2022       10          3.449318e+06
#            11          3.188625e+06
#            12          3.092768e+06
# 2023       1           5.735438e+06
#            2           3.506771e+06
#
# [112 rows x 1 columns]

# %%
rent.groupby(by=[rent.Date_Added.dt.year,  rent.Date_Added.dt.month]).agg({'Price':np.mean}).plot()
# Out:
# <AxesSubplot:xlabel='Date_Added,Date_Added'>

# %%
rent.groupby(by=[rent.Date_Added.dt.year, rent.Date_Added.dt.month]).agg({'Price': np.median}).plot()
# Out:
# <AxesSubplot:xlabel='Date_Added,Date_Added'>

# %% [markdown]
# In both charts, there's a spike from millions to 10s of millions in 2013. Let's see why.

# %%
rent.loc[rent['Date_Added'].dt.year == 2013]
# Out:
#                                      Title  \
# 31524    3 BEDROOM BLOCK OF FLATS FOR RENT
# 31526            5 BEDROOM DUPLEX FOR RENT
# 31527  4 BEDROOM FLAT & APARTMENT FOR RENT
#
#                                                 Location Listing_Type  \
# 31524                 Continental Road Ikosi Ketu Lagos          Rent
# 31526   Off Muri Okunola Victoria Island Victoria Isl...         Rent
# 31527   Olabode George Street Victoria Island Victori...         Rent
#
#                   City Location_Area       Price Date_Added Date_Updated  \
# 31524             Ketu      Mainland   1500000.0 2013-12-04   2013-12-04
# 31526  Victoria Island        Island  23550000.0 2013-10-25   2013-10-25
# 31527  Victoria Island        Island   5500000.0 2013-09-02   2013-09-02
#
#        Beds  Baths  Toilets  Location_Area_Encoded
# 31524   3.0    4.0      0.0                      0
# 31526   5.0    5.0      0.0                      1
# 31527   4.0    4.0      0.0                      1

# %%
rent.loc[rent['Date_Added'].dt.year == 2013]['Price'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# While the median is in the 5million range, the max value is over 20million. It is impossible to know if this value is an outlier, given the size of the 2013 dataset. We'll instead rechart without 2013 values.

# %%
avg_rent = rent.groupby(by=[rent.Date_Added.dt.year.loc[rent.Date_Added.dt.year > 2013]]).agg({'Price': np.mean})

median_rent = rent.groupby(by=[rent.Date_Added.dt.year.loc[rent.Date_Added.dt.year > 2013]]).agg({'Price': np.median})

# %%
plt.figure(figsize=(20,12))
fig, (ax1, ax2) = plt.subplots(2,1, sharex=True)
ax1.plot(avg_rent, color='blue', label='Average Rent')
ax1.legend()
ax2.plot(median_rent, color='green', label='Median Rent')
ax2.legend()
plt.tight_layout()

# %% [markdown]
# The trends say something interesting. It seems that there was a spike in rent from 2017 which cooled in 2022. There may be a number of reasons for this:
# 1. Many of the listings are from 2022 so there's a larger range for mean values
# 2. Prices did in fact drop in 2022
# 3. 2022 prices include listings from lower rent areas while earlier years may not.
#
# Let's review the dataframe to decide which of these is applicable

# %%
year_count = dict()
for i in range(2013, 2024):
    year_count[i] = len(rent.loc[rent['Date_Added'].dt.year == i])

year_count
# Out:
# {2013: 3,
#  2014: 884,
#  2015: 3567,
#  2016: 3498,
#  2017: 602,
#  2018: 924,
#  2019: 1050,
#  2020: 1533,
#  2021: 1879,
#  2022: 9941,
#  2023: 4440}

# %% [markdown]
# 2022 has many more listings than any other year. Let's generate samples of 1000 from the years having listings greater than 1000 and plot that chart.

# %%
y2014 = rent.loc[rent['Date_Added'].dt.year == 2014]
y2015 = rent.loc[rent['Date_Added'].dt.year == 2015].sample(1000)
y2016 = rent.loc[rent['Date_Added'].dt.year == 2016].sample(1000)
y2017 = rent.loc[rent['Date_Added'].dt.year == 2017]
y2018 = rent.loc[rent['Date_Added'].dt.year == 2018]
y2019 = rent.loc[rent['Date_Added'].dt.year == 2019].sample(1000)
y2020 = rent.loc[rent['Date_Added'].dt.year == 2020].sample(1000)
y2021 = rent.loc[rent['Date_Added'].dt.year == 2021].sample(1000)
y2022 = rent.loc[rent['Date_Added'].dt.year == 2022].sample(1000)
y2023 = rent.loc[rent['Date_Added'].dt.year == 2023].sample(1000)

rent_sample = pd.concat([y2014, y2015, y2016, y2017,
                         y2018, y2019, y2020, y2021,
                         y2022, y2023])

# %%
avg_rent_sample = rent_sample.groupby(by=[rent_sample.Date_Added.dt.year]).agg({'Price': np.mean})

median_rent_sample = rent_sample.groupby(by=[rent_sample.Date_Added.dt.year]).agg({'Price': np.median})

# %%
plt.figure(figsize=(20,12))
fig, (ax1, ax2) = plt.subplots(2,1, sharex=True)
ax1.plot(avg_rent_sample, color='blue', label='Average Rent')
ax1.legend()
ax2.plot(median_rent_sample, color='green', label='Median Rent')
ax2.legend()
plt.suptitle('Average v. Median Rent', weight='bold', size=10)
plt.tight_layout()

# %% [markdown]
# Surprisingly, the chart is still the same after reworking the year count values. This secondary chart confirms the claim that the cost of housing/ rent in Lagos ballooned in 2017 and peaked in 2021. Since 2022, we've seen a significant return to pre-2018 levels.

# %%
plt.figure(figsize=(20,12))

plt.plot(avg_rent_sample, color='blue', label='Average Rent')
plt.plot(median_rent_sample, color='green', label='Median Rent')
locs, labels = plt.yticks()
labels = ['1M', '2M', '3M', '4M', 
          '5M', '6M', '7M', '8M']
plt.yticks(ticks=locs, labels=labels)
plt.legend()
plt.title('Average v. Median Rent', weight='bold', size=30)
plt.show()

# %% [markdown]
# Let's consider how many cities are represented across the different years and then chart changes in rent for those cities, if they reflect the general mean/ median.

# %%
y2014 = rent.loc[rent['Date_Added'].dt.year == 2014]
y2015 = rent.loc[rent['Date_Added'].dt.year == 2015].sample(1000)
y2016 = rent.loc[rent['Date_Added'].dt.year == 2016].sample(1000)
y2017 = rent.loc[rent['Date_Added'].dt.year == 2017]
y2018 = rent.loc[rent['Date_Added'].dt.year == 2018]
y2019 = rent.loc[rent['Date_Added'].dt.year == 2019].sample(1000)
y2020 = rent.loc[rent['Date_Added'].dt.year == 2020].sample(1000)
y2021 = rent.loc[rent['Date_Added'].dt.year == 2021].sample(1000)
y2022 = rent.loc[rent['Date_Added'].dt.year == 2022].sample(1000)
y2023 = rent.loc[rent['Date_Added'].dt.year == 2023].sample(1000)

# %%
rent.loc[(rent['Date_Added'].dt.year == 2017) & (rent['City'] == 'Ikoyi')]
# Out:
#                                      Title  \
# 22876  3 BEDROOM FLAT & APARTMENT FOR RENT
# 22879           3 BEDROOM TERRACE FOR RENT
# 22883                      OFFICE FOR RENT
# 22888  3 BEDROOM FLAT & APARTMENT FOR RENT
# 22949         4 BEDROOM TOWNHOUSE FOR RENT
# ...                                    ...
# 23480  3 BEDROOM FLAT & APARTMENT FOR RENT
# 23486  3 BEDROOM FLAT & APARTMENT FOR RENT
# 23487  3 BEDROOM FLAT & APARTMENT FOR RENT
# 23517    2 BEDROOM BLOCK OF FLATS FOR RENT
# 23518    3 BEDROOM BLOCK OF FLATS FOR RENT
#
#                                                 Location Listing_Type   City  \
# 22876               Close 322 Banana Island Ikoyi Lagos          Rent  Ikoyi
# 22879           Banana Island Banana Island Ikoyi Lagos          Rent  Ikoyi
# 22883                     Glover Road Ikoyi Ikoyi Lagos          Rent  Ikoyi
# 22888              Parkview Parkview Estate Ikoyi Lagos          Rent  Ikoyi
# 22949           Second Avenue Banana Island Ikoyi Lagos          Rent  Ikoyi
# ...                                                  ...          ...    ...
# 23480                       Old Ikoyi Ikoyi Ikoyi Lagos          Rent  Ikoyi
# 23486   Parkview Estate, Ikoyi Parkview Estate Ikoyi ...         Rent  Ikoyi
# 23487                 Burdillion Road Ikoyi Ikoyi Lagos          Rent  Ikoyi
# 23517   Parkview Estate,ikoyi Lagos Parkview Estate I...         Rent  Ikoyi
# 23518   Parkview Estate,ikoyi Lagos Parkview Estate I...         Rent  Ikoyi
#
#       Location_Area       Price Date_Added Date_Updated  Beds  Baths  Toilets  \
# 22876        Island  15000000.0 2017-12-28   2017-12-28   3.0    4.0      0.0
# 22879        Island  13000000.0 2017-12-21   2017-12-21   3.0    2.0      0.0
# 22883        Island    100000.0 2017-12-18   2017-12-18   0.0    0.0      0.0
# 22888        Island   3500000.0 2017-12-11   2017-12-11   3.0    2.0      0.0
# 22949        Island  17000000.0 2017-11-08   2017-11-08   4.0    4.0      0.0
# ...             ...         ...        ...          ...   ...    ...      ...
# 23480        Island   7000000.0 2017-01-14   2017-01-14   3.0    3.0      4.0
# 23486        Island   3500000.0 2017-01-13   2017-01-13   3.0    3.0      3.0
# 23487        Island  12999996.0 2017-01-13   2017-01-13   3.0    3.0      4.0
# 23517        Island   2000000.0 2017-01-04   2017-01-04   2.0    2.0      3.0
# 23518        Island   2500000.0 2017-01-04   2017-01-04   3.0    3.0      4.0
#
#        Location_Area_Encoded
# 22876                      1
# 22879                      1
# 22883                      1
# 22888                      1
# 22949                      1
# ...                      ...
# 23480                      1
# 23486                      1
# 23487                      1
# 23517                      1
# 23518                      1
#
# [66 rows x 12 columns]

# %%
rent.groupby(by='City').agg(average_rent=('Price', np.mean), median_rent=('Price', np.median))
# Out:
#                  average_rent  median_rent
# City
# Agege            1.008014e+06     600000.0
# Ajah             1.815602e+06    1200000.0
# Alimosho         1.131742e+06     400000.0
# Apapa            4.359444e+06    3500000.0
# Badagry          1.335185e+06     400000.0
# Ebute Metta      1.071194e+06     800000.0
# Festac           1.548512e+06    1000000.0
# Gbagada          1.596139e+06    1300000.0
# Iju              9.080000e+05     400000.0
# Ikeja            2.881776e+06    1800000.0
# Ikorodu Road     1.382656e+06     700000.0
# Ikoyi            1.140903e+07   10800000.0
# Isheri           8.500000e+05     700000.0
# Isolo            1.138565e+06     700000.0
# Ketu             2.179849e+06    1500000.0
# Lekki            4.143285e+06    3500000.0
# Mushin           6.520455e+05     475000.0
# Oshodi           1.627238e+06    1000000.0
# Surulere         1.474880e+06    1200000.0
# Victoria Island  7.191518e+06    6000000.0
# Yaba             1.214407e+06     850000.0

# %%
avg_rent_sample = rent_sample.groupby(by=[rent_sample.Date_Added.dt.year]).agg({'Price': np.mean})

median_rent_sample = rent_sample.groupby(by=[rent_sample.Date_Added.dt.year]).agg({'Price': np.median})

# %%
avg_city_yr = rent.groupby(by=[rent.Date_Added.dt.year, rent.City]).agg({'Price': np.mean}).reset_index().set_index('Date_Added')
median_city_yr = rent.groupby(by=[rent.Date_Added.dt.year, rent.City]).agg({'Price': np.median}).reset_index().set_index('Date_Added')

# %%
avg_city_yr
# Out:
#                        City         Price
# Date_Added
# 2013                   Ketu  1.500000e+06
# 2013        Victoria Island  1.452500e+07
# 2014                  Agege  5.100000e+05
# 2014                   Ajah  1.716176e+06
# 2014               Alimosho  3.000000e+05
# ...                     ...           ...
# 2023                  Lekki  4.589587e+06
# 2023                 Oshodi  1.500000e+06
# 2023               Surulere  1.380000e+06
# 2023        Victoria Island  7.562731e+06
# 2023                   Yaba  1.411720e+06
#
# [193 rows x 2 columns]

# %%
plt.plot(avg_city_yr.loc[avg_city_yr['City'] == 'Ikoyi']['Price'],
         color='blue', label='Average Rent')
plt.plot(median_city_yr.loc[median_city_yr['City'] == 'Ikoyi']['Price'], color='green', label='Median Rent')
locs, labels = plt.yticks()
labels = ['8M', '8.5M', '9M', '9.5M',
          '10M', '10.5M', '11M', '11.5M',
          '12M', '12.5M', '13M']
plt.yticks(ticks=locs, labels=labels)
plt.legend(loc='upper left', bbox_to_anchor=[1, 1])
plt.title('Average v. Median Rent in Ikoyi, Lagos', weight='bold', size=20)
plt.show()

# %%
plt.plot(avg_city_yr.loc[avg_city_yr['City'] == 'Victoria Island'].loc[2014:]['Price'],
         color='blue', label='Average Rent')
plt.plot(median_city_yr.loc[median_city_yr['City'] == 'Victoria Island'].loc[2014:]['Price'], color='green', label='Median Rent')
locs, labels = plt.yticks()
labels = ['2M', '4M', '6M', '8M',
          '10M', '12M', '14M', '16M']
plt.yticks(ticks=locs[1:-1], labels=labels[1:-1])
plt.legend(loc='upper left', bbox_to_anchor=[1, 1])
plt.title('Average v. Median Rent in VI, Lagos', weight='bold', size=20)
plt.show()

# %%
plt.plot(avg_city_yr.loc[avg_city_yr['City'] == 'Lekki']['Price'],
         color='blue', label='Average Rent')
plt.plot(median_city_yr.loc[median_city_yr['City'] == 'Lekki']['Price'], color='green', label='Median Rent')
locs, labels = plt.yticks()
labels = ['2.7M', '3M', '3.2M', '3.5M', '3.7M',
          '4M', '4.2M', '4.5M', '4.7M', '5M']
plt.yticks(ticks=locs, labels=labels)
plt.legend(loc='upper left', bbox_to_anchor=[1, 1])
plt.title('Average v. Median Rent in Lekki, Lagos', weight='bold', size=20)
plt.show()

# %%
plt.plot(avg_city_yr.loc[avg_city_yr['City'] == 'Yaba']['Price'],
         color='blue', label='Average Rent')
plt.plot(median_city_yr.loc[median_city_yr['City'] == 'Yaba']['Price'], color='green', label='Median Rent')
locs, labels = plt.yticks()
labels = ['0', '500K', '1M', '1.5M', '2M',
          '2.5M', '3M', '3.5M', '4M',
          '4.5M', '5M']
plt.yticks(ticks=locs, labels=labels)
plt.legend(loc='upper left', bbox_to_anchor=[1, 1])
plt.title('Average v. Median Rent in Yaba, Lagos', weight='bold', size=20)
plt.show()

# %%
plt.plot(avg_city_yr.loc[avg_city_yr['City'] == 'Surulere']['Price'],
         color='blue', label='Average Rent')
plt.plot(median_city_yr.loc[median_city_yr['City'] == 'Surulere']['Price'], color='green', label='Median Rent')
locs, labels = plt.yticks()
labels = ['0M', '1M', '2M', '3M',
          '4M', '5M', '6M']
plt.yticks(ticks=locs, labels=labels)
plt.legend(loc='upper left', bbox_to_anchor=[1, 1])
plt.title('Average v. Median Rent in Surulere, Lagos', weight='bold', size=20)
plt.show()

# %%
plt.plot(avg_city_yr.loc[avg_city_yr['City'] == 'Ikeja']['Price'],
         color='blue', label='Average Rent')
plt.plot(median_city_yr.loc[median_city_yr['City'] == 'Ikeja']['Price'], color='green', label='Median Rent')
locs, labels = plt.yticks()
labels = ['1M', '1.5M', '2M', '2.5M',
          '3M', '3.5M', '4M', '4.5M', '5M']
plt.yticks(ticks=locs, labels=labels)
plt.legend(loc='upper left', bbox_to_anchor=[1, 1])
plt.title('Average v. Median Rent in Ikeja, Lagos', weight='bold', size=20)
plt.show()

# %% [markdown]
# ### Analytical Questions
#
# This section will address analytical questions raised.

# %% [markdown]
# ##### What is the average rent per city in Lagos?

# %%
rent.groupby('City').agg({'Price': np.mean}).sort_values('Price', ascending=False).applymap('{:,.2f}'.format)

# %% [markdown]
# ##### What is the median rent per city in Lagos?

# %%
rent.groupby('City').agg({'Price': np.median}).sort_values('Price', ascending=False).applymap('{:,.2f}'.format)
# Out:
#                          Price
# City
# Ikoyi            10,800,000.00
# Victoria Island   6,000,000.00
# Apapa             3,500,000.00
# Lekki             3,500,000.00
# Ikeja             1,800,000.00
# Ketu              1,500,000.00
# Gbagada           1,300,000.00
# Surulere          1,200,000.00
# Ajah              1,200,000.00
# Festac            1,000,000.00
# Oshodi            1,000,000.00
# Yaba                850,000.00
# Ebute Metta         800,000.00
# Ikorodu Road        700,000.00
# Isolo               700,000.00
# Isheri              700,000.00
# Agege               600,000.00
# Mushin              475,000.00
# Iju                 400,000.00
# Badagry             400,000.00
# Alimosho            400,000.00

# %%
avg_rent_city = rent.groupby('City').agg({'Price': np.mean}).sort_values(by='Price', ascending=False).reset_index()
avg_rent_city = avg_rent_city.sort_values('Price').set_index('City')

med_rent_city = rent.groupby('City').agg({'Price': np.median}).sort_values(by='Price', ascending=False).reset_index()
med_rent_city = med_rent_city.sort_values('Price').set_index('City')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 12))
ax1.barh(avg_rent_city.index, avg_rent_city['Price'])
ax2.barh(med_rent_city.index, med_rent_city['Price'])
fig.suptitle('Average v. Median Rent \n Per City', size=30, weight='bold')
plt.tight_layout()
plt.show()

# %%
# Plot cross barh

# %% [markdown]
# ##### What are the cities with the highest and lowest rents (actual, mean, median)?
# The top 5 cities per average & median rent are Ikoyi, Victoria Island, Apapa, Lekki & Ikeja. Agege, Iju & Mushin are in the bottom average and median rent range.

# %% [markdown]
# ##### Which cities provide property with rents within mean and median values.

# %%
rent_mean = rent['Price'].mean()
f'{rent_mean:,.2f}'

# %% [markdown]
# The top 2 cities by average rent are the only cities with average rents above the dataset average. This confirms the left skewed nature of the distribution.

# %%
rent_median = rent['Price'].median()
f'{rent_median:,.2f}'

# %% [markdown]
# The top 4 cities by median rents are the only cities with median rents above the dataset median.

# %% [markdown]
# 3. Which cities provide property with rents within mean and median values.
# 4. For a person of X income range, what cities provide optimum rental value for a single person, a married couple, a family of 5 (the average family size in Lagos)?
# 5. Visualize and explain the correlation if any between number of bedrooms and bathrooms and rental value.
# 6. Visualize and explain the correlation if any, between the number of bedrooms and bathroom and city.
# 7. What is the state of affordable housing in Lagos?
#     a. What is the median income in Lagos?
#     b. How much of the property market in available within that range?
#     c. Ratio of demand (available renters) v. supply (number of property within their range)
# 8. What does the dataset tell us about the housing deficit and the skewed housing market in Lagos?
# 9. The rate of change / inflation in the Lagos real estate market
# 10. ...
